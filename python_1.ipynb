# %%
print("Hello Mydeargreattherch!geargadrhaerhath")
# Out:
# Hello Mydeargreattherch!

# %% [markdown]
# #受難日第一日20190923
# ##程式超簡單

# %%
print("   * ")
print("  ***")
print(" *****")
print("   * ")
print("   * ")
print("   * ")
# Out:
#    *
#   ***
#  *****
#    *
#    *
#    *

# %%
x = input('Enter your name:')
print('Hello, ' + x)
# Out:
# Enter your name:toad
# Hello, toad

# %%
a = input("請輸入：")
a
# Out:
# 請輸入：100
# '100'

# %%
a = input("請輸入：")
a
b=a+1
b
# Out:
# 請輸入：100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c41d06678cb4> in <module>()
#       1 a = input("請輸入：")
#       2 a
# ----> 3 b=a+1
#       4 b
#
# TypeError: must be str, not int

# %%
a = int(input("請輸入："))
a
b=a+1
b
# Out:
# 請輸入：100
# 101
